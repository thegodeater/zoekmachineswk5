# %% [markdown]
# # Assignment  Practice Text classification with Naive Bayes

# %% [markdown]
# ## Notebook made by   (If not filled in correctly: 0 pts for assignment)
#
# __Name(s)__:
#
# __Student id(s)__ :
#
# ### Pledge (taken from [Coursera's Honor Code](https://www.coursera.org/about/terms/honorcode) )
#
#
#
# Put here a selfie with your photo where you hold a signed paper with the following text: (if this is team work, put two selfies here). The link must be to some place on the web, not to a local file. **Assignments without the selfies will not be graded and receive 0 points.**
#
# > My answers to homework, quizzes and exams will be my own work (except for assignments that explicitly permit collaboration).
#
# >I will not make solutions to homework, quizzes or exams available to anyone else. This includes both solutions written by me, as well as any official solutions provided by the course staff.
#
# >I will not engage in any other activities that will dishonestly improve my results or dishonestly improve/hurt the results of others.
#
# <img src='link to your selfie'/>

# %% [markdown]
# # Practice Text classification with Naive Bayes
#
#
#
# <h3>Abstract</h3>
# <p>We will do text classification on a collection of Dutch parliamentary questions.
#     The website <a href="https://zoek.officielebekendmakingen.nl/zoeken/parlementaire_documenten">officielebekendmakingen.nl</a>lets you search in "kamervragen".
#     <!--You can donwload
#     <a href='http://data.politicalmashup.nl/kamervragen/PoliDocs_Kamervragen.zip'>this zipfile with Kamervragen in XML</a>
#     to see some of the  data in XML format.
#     It also contains style sheets to show the XML well in a browser.
# -->
#     The <a href='http://maartenmarx.nl/teaching/zoekmachines/LectureNotes/MySQL/'>MYSQL directory</a> contains an <a href='http://maartenmarx.nl/teaching/zoekmachines/LectureNotes/MySQL/KVR14807.xml'>example   Kamervraag XML file</a> and a file `kvr.csv.gz` with 40K kamervragen in a handy csv format. Note that in your browser you see the result of applying stylesheets. So choose View Source or open it in an editor.</p>
#
# <h3>First exploration</h3>
#
# See below.
#
# <h2>Exercises</h2>
#
# <p>We will use the fields in elements of the form <tt> &lt;item attribuut="Afkomstig_van"></tt> as our classes.
#     These are the ministeries to whom the question is addressed.
#     An example is
#     <pre>
#         &lt;item attribuut="Afkomstig_van">Landbouw, Natuurbeheer en Visserij (LNV)&lt;/item>
#     </pre>
#     Note that these labels are <strong>not normalized</strong>, see e.g. the counts below:
#     <pre>
# Justitie (JUS)                                                   3219
# Volksgezondheid, Welzijn en Sport (VWS)                          2630
# Buitenlandse Zaken (BUZA)                                        1796
# Verkeer en Waterstaat (VW)                                       1441
# Justitie                                                         1333
# Sociale Zaken en Werkgelegenheid (SZW)                           1231
# Onderwijs, Cultuur en Wetenschappen (OCW)                        1187
# Volkshuisvesting, Ruimtelijke Ordening en Milieubeheer (VROM)     984
# FinanciÃ«n (FIN)                                                   960
# Volksgezondheid, Welzijn en Sport                                 951
# Economische Zaken (EZ)                                            946
# Buitenlandse Zaken                                                753
# Binnenlandse Zaken en Koninkrijksrelaties (BZK)                   725
# Verkeer en Waterstaat                                             724
# Defensie (DEF)                                                    646
# Sociale Zaken en Werkgelegenheid                                  607
# Landbouw, Natuurbeheer en Visserij (LNV)                          586
# Volkshuisvesting, Ruimtelijke Ordening en Milieubeheer            554
# Onderwijs, Cultuur en Wetenschappen                               532
# Vreemdelingenzaken en Integratie (VI)                             466
#     </pre>
# </p>
#
# <ol>
#   <li>Normalize the values for "ministerie" and choose 10 ministeries to work with. </li>
#   <li>Implement the two algorithms in Fig MRS.13.2, using your earlier code for creating term and document frequencies.
#   It might be easier to use the representation and formula given in MRS section 13.4.1.</li>
#   <li>On this collection, train NB text classifiers for 10 different classes with enough and interesting data.</li>
#   <li>Compute for each term and each of your 10 classes its utility for that class using mutual information.</li>
#   <li>For each class, show the top 10 words as in Figure 13.7 in MRS.</li>
#   <li>Evaluate your classifiers using Precision, Recall and F1. (
#        <br/>
#       Give a table in which you show these values for using the top 10, top 100 terms and all terms, for all of your 10 classes.
#       Thus do feature selection per class, and use for each class the top n best features for that class.
#       <br/>
#   Also show the microaverage(s) for all 10 classes together.
#   <br/>
#   If you like you can also present this in a figure like MRS.13.8.
#   Then compute the F1 measure for the same number of terms as in that figure.</li>
# <li> You have done the complete implementation by yourself. Congratulations! You can also use `scikit-learn` routines for all of this work. Do that. So follow [this text classification tutorial](http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html)  and implement the same steps but now with your kamervragen dataset. Also use [mutual information feature selection](http://scikit-learn.org/stable/modules/feature_selection.html) to select the K-best features, and compare the results as before.
# </li>
#   <li>Reflect and report briefly about your choices in this process and about the obtained results. Also reflect on the differences between the scikit learn approach and the "own implementation approach".</li>
# </ol>
#
# <h3>Training/Testing</h3>
# <p>It is important that you do not test your classifier using documents that have also been used in training.
#     So split up your collection in a training set and a test set. A 80%-20% split is reasonable.
#
# <br/>
#     If you have too little data you can use 5 or <a href="http://en.wikipedia.org/wiki/Cross-validation_(statistics)#k-fold_cross-validation">10-fold cross validation</a>.</p>
#
# <!--
# <h2>Form of presentation</h2>
# <ul>
#     <li>Make slides or wikipages and have your system running (this could just be an IPython notebook with a classify function that accepts any string and classifies it.) ~~and be able to accept documents from the web.~~ </li>
#     <li>Create one or two slides or wikipages for each of the sub exercises listed above.
# </li>
# <li>Make it clear in the heading of the slides which sub exercises you talk about.</li>
#     <li>Show running code with one or two  good examples (a TP of course, but also a FP and an error-analysis is nice to show). </li>
# </ul>
# -->
#
# <h2>Form of handing in your final product</h2>
#
# * An IPython notebook with for each question, a MarkDown cell containing the question, a code cell which solves the question, an output cell with the output, followed by a MarkDown cell with explanation/reflection

# %% [markdown]
# # Some example code

# %%
import pandas as pd

names=['jaar', 'partij','titel','vraag','antwoord','ministerie']

# Change to KVR1000.csv.gz if this becomes to0 slow for you
kvrdf= pd.read_csv('http://maartenmarx.nl/teaching/zoekmachines/LectureNotes/MySQL/KVR.csv.gz', 
                   compression='gzip', sep='\t', 
                   index_col=0, names=names,
                   ) 

for kolom in names[1:]:
    kvrdf[kolom]= kvrdf[kolom].astype(str)
print(kvrdf.shape)
kvrdf.head(100)
# Out:
# (40516, 6)
#                 jaar       partij  \
# KVR1000.xml     1994         PvdA
#  KVR10000.xml   1999         PvdA
#  KVR10001.xml   1999           SP
#  KVR10002.xml   1999         PvdA
#  KVR10003.xml   1999         PvdA
#  KVR10004.xml   1999          D66
#  KVR10006.xml   1999         PvdA
#  KVR10007.xml   1999          D66
#  KVR10008.xml   1999   GroenLinks
#  KVR10009.xml   1999           SP
#  KVR1001.xml    1994   GroenLinks
#  KVR10010.xml   1999          CDA
#  KVR10011.xml   1999          SGP
#  KVR10013.xml   1999   GroenLinks
#  KVR10014.xml   1999         PvdA
#  KVR10016.xml   1999          CDA
#  KVR10017.xml   1999           SP
#  KVR10018.xml   1999          CDA
#  KVR10019.xml   1999          CDA
#  KVR1002.xml    1994          GPV
#  KVR10020.xml   1999   GroenLinks
#  KVR10021.xml   1999          VVD
#  KVR10023.xml   1999         PvdA
#  KVR10024.xml   1999          CDA
#  KVR10025.xml   1999          CDA
#  KVR10027.xml   1999         PvdA
#  KVR1003.xml    1994          D66
#  KVR10031.xml   1999          CDA
#  KVR10032.xml   1999   GroenLinks
#  KVR10033.xml   1999          D66
# ...              ...          ...
#  KVR10079.xml   1999          VVD
#  KVR1008.xml    1994          SGP
#  KVR10080.xml   1999          CDA
#  KVR10084.xml   1999          CDA
#  KVR10085.xml   1999   GroenLinks
#  KVR10086.xml   1999           SP
#  KVR10087.xml   1999   GroenLinks
#  KVR10088.xml   1999   GroenLinks
#  KVR10089.xml   1999          CDA
#  KVR1009.xml    1994          CDA
#  KVR10090.xml   1999           SP
#  KVR10091.xml   1999           SP
#  KVR10092.xml   1999         PvdA
#  KVR10093.xml   1999   GroenLinks
#  KVR10094.xml   1999          CDA
#  KVR10095.xml   1999          CDA
#  KVR10096.xml   1999          CDA
#  KVR10097.xml   1999          CDA
#  KVR10098.xml   1999           SP
#  KVR10099.xml   1999   GroenLinks
#  KVR1010.xml    1995          VVD
#  KVR10100.xml   1999          CDA
#  KVR10101.xml   1999          CDA
#  KVR10102.xml   1999           SP
#  KVR10103.xml   1999   GroenLinks
#  KVR10104.xml   1999          CDA
#  KVR10105.xml   1999          CDA
#  KVR10106.xml   1999   GroenLinks
#  KVR10107.xml   1999          CDA
#  KVR10108.xml   1999          CDA
#
#                                                            titel  \
# KVR1000.xml     De vragen betreffen de betrouwbaarheid van de...
#  KVR10000.xml   Vragen naar aanleiding van berichten (uitzend...
#  KVR10001.xml   Vragen naar aanleiding van de berichten "Nede...
#  KVR10002.xml   Vragen over de gebrekkige opvang van verpleeg...
#  KVR10003.xml   Vragen over onbetrouwbaarheid van filemeldingen.
#  KVR10004.xml   Vragen naar aanleiding van het bericht in de ...
#  KVR10006.xml
#  KVR10007.xml   Vragen naar aanleiding van het artikel ''Eila...
#  KVR10008.xml   Vragen over de mogelijke terugkeer naar het o...
#  KVR10009.xml   Vragen over de uiteindelijke invulling van ui...
#  KVR1001.xml    De vragen betreffen subsidiëring van (een haa...
#  KVR10010.xml   Aanvullende vragen op die gesteld door het li...
#  KVR10011.xml   Vragen over de introductie van de zogenaamde ...
#  KVR10013.xml   Vragen naar aanleiding van het artikel "Een h...
#  KVR10014.xml   Vragen over het feit dat de Roma-zigeuners he...
#  KVR10016.xml   Vragen over het verbod van de Europese Commis...
#  KVR10017.xml   Vragen naar aanleiding van een geval van hulp...
#  KVR10018.xml   Vragen over de bestemming van grond die bij h...
#  KVR10019.xml
#  KVR1002.xml    De vragen betreffen een voorgenomen voorstel ...
#  KVR10020.xml   Vragen over het hygienisch en/of steriel werk...
#  KVR10021.xml   Vragen over een bericht dat gerechtsdeurwaard...
#  KVR10023.xml   Vragen over de gevolgen van de proefboringen ...
#  KVR10024.xml   Vragen naar aanleiding van het artikel ''Zwar...
#  KVR10025.xml   Vragen over versnelde verdubbeling van het aa...
#  KVR10027.xml   Vragen over de uitvoeringsregels PGB (persoon...
#  KVR1003.xml    De vragen betreffen een voorgenomen voorstel ...
#  KVR10031.xml   Vraag n.a.v. krantenbericht "Nederland is iet...
#  KVR10032.xml   Vragen naar aanleiding van de berichtgeving i...
#  KVR10033.xml   Vragen over de notitie over ministeriële vera...
# ...                                                          ...
#  KVR10079.xml   Vragen naar aanleiding van een bericht in het...
#  KVR1008.xml
#  KVR10080.xml   Vragen over uitstel voor deelname door vrouwe...
#  KVR10084.xml   Vragen gaan in op een artikel in het Financie...
#  KVR10085.xml   Vragen naar aanleiding van het artikel "De ov...
#  KVR10086.xml   Aanvullende vragen over het artikel "RIVM erk...
#  KVR10087.xml   Vragen naar aanleiding van het onvrijwillige ...
#  KVR10088.xml          Vragen over de toename van zwerfjongeren.
#  KVR10089.xml   Vragen over het grote aanbod van illegale arb...
#  KVR1009.xml    De vragen betreffen mogelijkheden tot product...
#  KVR10090.xml   Vragen over een toeslag voor ministers en sta...
#  KVR10091.xml
#  KVR10092.xml   Vragen over de levering van stroomaggregaten ...
#  KVR10093.xml   De vragen gaan met name in op de ESF-subsidie...
#  KVR10094.xml   Vragen naar aanleiding van het bericht "Korth...
#  KVR10095.xml   Vragen naar aanleiding van het artikel "Amste...
#  KVR10096.xml   Vragen naar aanleiding van een onderzoek van ...
#  KVR10097.xml   Vragen over de financiele problemen van de Am...
#  KVR10098.xml   Vragen naar aanleiding van het tv-programma '...
#  KVR10099.xml   Vragen over mogelijke vertraging van de reali...
#  KVR1010.xml    De vragen betreffen de foutieve inschatting v...
#  KVR10100.xml   Vragen naar aanleiding van twee artikelen ove...
#  KVR10101.xml   Aanvullende vragen over mogelijke vertraging ...
#  KVR10102.xml   Vragen over de fiscale aspecten van bijleenhy...
#  KVR10103.xml   Vragen naar aanleiding van het Teletekst-beri...
#  KVR10104.xml   Vragen over een ''Twee Vandaag''-uitzending (...
#  KVR10105.xml   Vragen naar aanleiding van een artikel in Spi...
#  KVR10106.xml   Vragen over de betrouwbaarheid van de Nederla...
#  KVR10107.xml   Vragen naar aanleiding van het bericht in Tro...
#  KVR10108.xml   Vragen gaan in op de fors opgelopen wachttijd...
#
#                                                            vraag  \
# KVR1000.xml     Hebt u kennisgenomen van het televisieprogram...
#  KVR10000.xml   Kent u de berichten over de situatie in de Me...
#  KVR10001.xml   Kent u de berichten «Nederland steunt de Soeh...
#  KVR10002.xml   Kent u het bericht over onderzoek van Nu91 me...
#  KVR10003.xml   Hebt u kennisgenomen van de berichten over de...
#  KVR10004.xml   Kent u het bericht als zou het RIVM onjuiste ...
#  KVR10006.xml   Kent u berichten over asbestgevaar voor KFOR-...
#  KVR10007.xml   Kent u het artikel Eilander artsen vechten vo...
#  KVR10008.xml   Kent u het artikel «De specialist declareert ...
#  KVR10009.xml   Is over de uiteindelijke invulling van de uit...
#  KVR1001.xml    Wilt u de pre´-haalbaarheidsstudie naar de mo...
#  KVR10010.xml   Heeft u in een brief aan artsen, apothekers e...
#  KVR10011.xml   Kent u de berichtgeving rond de introductie v...
#  KVR10013.xml   Bent u op de hoogte van de huidige situatie i...
#  KVR10014.xml   Heeft u kennisgenomen van de door het Europea...
#  KVR10016.xml   Heeft de Europese Commissie de door de regeri...
#  KVR10017.xml   Hebt u kennisgenomen van de verslaglegging in...
#  KVR10018.xml   Komt bij het boren van tunnels grond vrij die...
#  KVR10019.xml   Hoe luidt exact de uitspraak van de WTO inzak...
#  KVR1002.xml    Heeft de Franse minister van Buitenlandse Zak...
#  KVR10020.xml   Hoeveel tatoeëerders en piercers zijn in Nede...
#  KVR10021.xml   Is het bericht waar dat ruim 55 gerechtsdeurw...
#  KVR10023.xml   Bent u op de hoogte van de gang van zaken bij...
#  KVR10024.xml   Kent u het artikel «Zwarthandel EK-kaarten wo...
#  KVR10025.xml   Is het u bekend dat de N31, met name het traj...
#  KVR10027.xml   Hebt u kennisgenomen van de brief van de Fede...
#  KVR1003.xml    Kent u uitspraken van de Franse minister voor...
#  KVR10031.xml   Hebt u kennisgenomen van de uitspraken van de...
#  KVR10032.xml   Hebt u kennisgenomen van de berichtgeving ove...
#  KVR10033.xml   Wat is de status van de notitie van uw Secret...
# ...                                                          ...
#  KVR10079.xml   Is het waar dat het college van Burgemeester ...
#  KVR1008.xml    Zijn bij een Indonesische militaire actie teg...
#  KVR10080.xml   Hoeveel vrouwen krijgen door gebrek aan kinde...
#  KVR10084.xml   Heeft de Europese Commissie de Nederlandse vo...
#  KVR10085.xml   Kent u het artikel «De overheid lokt milieucr...
#  KVR10086.xml   Kent u het artikel «RIVM erkent: milieuvoorde...
#  KVR10087.xml   Bent u op de hoogte van het feit dat de enige...
#  KVR10088.xml   Herinnert u zich de antwoorden op de vragen o...
#  KVR10089.xml   Kent u het artikel «Hoogtijdagen voor de ille...
#  KVR1009.xml    Hebt u kennisgenomen van het IMSA-rapport, in...
#  KVR10090.xml   Is aan bewindspersonen die een duurdere diens...
#  KVR10091.xml   Kent u het rapport «Gevangen in banenplannen»...
#  KVR10092.xml   Bent u op de hoogte van de levering door het ...
#  KVR10093.xml   Kent u het bericht dat de Arbeidsvoorziening ...
#  KVR10094.xml   Bent u op de hoogte van het bericht «Korthals...
#  KVR10095.xml   Heeft u kennisgenomen van het bericht «Amster...
#  KVR10096.xml   Bent u op de hoogte van het onderzoek van TNO...
#  KVR10097.xml   Herinnert u zich mijn eerdere vragen van 22 j...
#  KVR10098.xml   Hebt u kennisgenomen van de uitzending van «L...
#  KVR10099.xml   Hebt u kennisgenomen van het artikel «Aanslui...
#  KVR1010.xml    Herinnert u zich uw uitspraak gedaan tijdens ...
#  KVR10100.xml   Kent u een tweetal artikelen over hypotheekre...
#  KVR10101.xml   Is het bericht juist dat er een nieuw onderzo...
#  KVR10102.xml   Kent u het artikel «Hypotheekaftrek (II)»? St...
#  KVR10103.xml   Hebt u kennisgenomen van de laatste cijfers v...
#  KVR10104.xml   Hebt u kennisgenomen van de uitzending van Tw...
#  KVR10105.xml   Is het u bekend dat de tabaksindustrie chemis...
#  KVR10106.xml   Kent u het bericht «Controle op dioxine deugt...
#  KVR10107.xml   Kent u het bericht dat «ziekenhuizen gespecia...
#  KVR10108.xml   Heeft u kennisgenomen van de ongerustheid van...
#
#                                                         antwoord  \
# KVR1000.xml     Ja. Het bedoelde geluidmeetpunt is eigendom v...
#  KVR10000.xml
#  KVR10001.xml
#  KVR10002.xml   Ja. Het onderzoek van NU’91 wijst uit dat het...
#  KVR10003.xml   Ja. Nee. Door de waarnemers van het Algemeen ...
#  KVR10004.xml   Ja. Nee. Als reactie op het Volkskrant-artike...
#  KVR10006.xml                          Kamerstuk 22 181, nr. 293
#  KVR10007.xml   Ja. Ik ben van mening, en ga er vanuit dat di...
#  KVR10008.xml   Ja. Neen, op dit moment is in drie van de rui...
#  KVR10009.xml   De Ziekenfondsraad, thans College voor zorgve...
#  KVR1001.xml    Het rapport van deze studie is nog niet geree...
#  KVR10010.xml   Ja, het betreft zelfzorggeneesmiddelen die in...
#  KVR10011.xml   Ja. Het geneesmiddel Mifegyne betreft een gen...
#  KVR10013.xml   Ja. Vele sectoren in de Surinaamse samenlevin...
#  KVR10014.xml   Ja. Deze berichten zijn zorgwekkend. Zij corr...
#  KVR10016.xml   Deels. De Europese Commissie heeft een gedeel...
#  KVR10017.xml   Ja. Het betrof een geval van hulp bij zelfdod...
#  KVR10018.xml   Er komt inderdaad grond vrij dat vermengd wor...
#  KVR10019.xml
#  KVR1002.xml    Ja. Frankrijk is voornemens dit voorstel tijd...
#  KVR10020.xml   Het is niet bekend hoeveel tatoeëerders en pi...
#  KVR10021.xml   Bijlage ter inzage gelegd bij de afdeling Par...
#  KVR10023.xml   Ja. De m.e.r.-procedure is inmiddels volledig...
#  KVR10024.xml
#  KVR10025.xml   Ja, het is mij bekend dat zich op de N31, met...
#  KVR10027.xml   Bijlagen ter inzage gelegd bij de afdeling Pa...
#  KVR1003.xml    Ja. Nee, minister Lamassoure heeft inmiddels ...
#  KVR10031.xml   Ja. Blijkens een recente brief van de gemeent...
#  KVR10032.xml   Ja. De desbetreffende notitie wordt hierbij o...
#  KVR10033.xml   De notitie had tot doel als gespreksbasis te ...
# ...                                                          ...
#  KVR10079.xml   Het beleid van de gemeente Tilburg is erop ge...
#  KVR1008.xml    Doorgaans betrouwbare bronnen hebben deze ber...
#  KVR10080.xml   Volgens informatie, aangeleverd door de gemee...
#  KVR10084.xml   Op 7 juli jl. heb ik een gesprek gehad met de...
#  KVR10085.xml
#  KVR10086.xml   Ja. Ja. Naar aanleiding van de berichten in d...
#  KVR10087.xml   Ja. Betrokkenen zijn respectievelijk 1 septem...
#  KVR10088.xml   Ja. Over de opzet van het onderzoek heb ik ee...
#  KVR10089.xml   Ja. Het uitzendbureau «Prof» is op grond van ...
#  KVR1009.xml    Ja. De afgelopen jaren hebben diverse institu...
#  KVR10090.xml   In het Besluit van 26 januari 1999 (Stb. 127)...
#  KVR10091.xml   Ja. Deze bevindingen komen overeen met mijn w...
#  KVR10092.xml   Hoewel de regering bij haar oordeel blijft da...
#  KVR10093.xml   Ja. Ja. In de jaren 1995, 1996 en 1997 is zow...
#  KVR10094.xml   Ja. Het bericht is ontleend aan een interview...
#  KVR10095.xml   Ja. Op 19 januari 1998 zond de minister van V...
#  KVR10096.xml   Ja. In het rapport wordt overigens niet gespr...
#  KVR10097.xml   Ja. Gedeputeerde Staten van Zeeland hebben mi...
#  KVR10098.xml   Ja, ik heb kennis genomen van de bedoelde uit...
#  KVR10099.xml   Ja. Het bericht betreft een studie in opdrach...
#  KVR1010.xml    Ja. Ja. Ja. Op 17 juni 1994 had Intomart aan ...
#  KVR10100.xml   Ja. Zoals ik ook al heb geantwoord op vragen ...
#  KVR10101.xml   Het betreft een studie die wordt uitgevoerd i...
#  KVR10102.xml   Ja. Betaalde hypotheekrente die betrekking he...
#  KVR10103.xml   Ja, waarbij ik opmerk dat het hier gaat om ee...
#  KVR10104.xml   Ja. Het 1 (NL)Kmar peloton is aanvankelijk in...
#  KVR10105.xml   Ook ik heb via de media moeten vernemen dat d...
#  KVR10106.xml   Ja. De rapportage van de inspectiemissie van ...
#  KVR10107.xml   Ja. Ik kan deze stelling bevestigen noch ontk...
#  KVR10108.xml   Ja. Bij brief van 8 juli 1999 heb ik van de P...
#
#                                                       ministerie
# KVR1000.xml                                Verkeer en Waterstaat
#  KVR10000.xml                                           Justitie
#  KVR10001.xml                                          Financien
#  KVR10002.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10003.xml                              Verkeer en Waterstaat
#  KVR10004.xml                              Verkeer en Waterstaat
#  KVR10006.xml                                           Defensie
#  KVR10007.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10008.xml            Volksgezondheid, Welzijn en Sport (VWS)
#  KVR10009.xml            Volksgezondheid, Welzijn en Sport (VWS)
#  KVR1001.xml                  Landbouw, Natuurbeheer en Visserij
#  KVR10010.xml            Volksgezondheid, Welzijn en Sport (VWS)
#  KVR10011.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10013.xml                                                nan
#  KVR10014.xml                                                nan
#  KVR10016.xml                                          Financien
#  KVR10017.xml                                           Justitie
#  KVR10018.xml                              Verkeer en Waterstaat
#  KVR10019.xml                 Landbouw, Natuurbeheer en Visserij
#  KVR1002.xml                                  Buitenlandse Zaken
#  KVR10020.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10021.xml                                           Justitie
#  KVR10023.xml                                  Economische Zaken
#  KVR10024.xml                                                nan
#  KVR10025.xml                              Verkeer en Waterstaat
#  KVR10027.xml                  Volksgezondheid, Welzijn en Sport
#  KVR1003.xml                                  Buitenlandse Zaken
#  KVR10031.xml   Volkshuisvesting, Ruimtelijke Ordening en Mil...
#  KVR10032.xml                                Algemene Zaken (AZ)
#  KVR10033.xml                                Algemene Zaken (AZ)
# ...                                                          ...
#  KVR10079.xml                   Sociale Zaken en Werkgelegenheid
#  KVR1008.xml                                  Buitenlandse Zaken
#  KVR10080.xml                                                nan
#  KVR10084.xml                             Economische Zaken (EZ)
#  KVR10085.xml   Volkshuisvesting, Ruimtelijke Ordening en Mil...
#  KVR10086.xml                              Verkeer en Waterstaat
#  KVR10087.xml                Onderwijs, Cultuur en Wetenschappen
#  KVR10088.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10089.xml                   Sociale Zaken en Werkgelegenheid
#  KVR1009.xml                  Landbouw, Natuurbeheer en Visserij
#  KVR10090.xml                                                nan
#  KVR10091.xml                   Sociale Zaken en Werkgelegenheid
#  KVR10092.xml                                  Economische Zaken
#  KVR10093.xml                   Sociale Zaken en Werkgelegenheid
#  KVR10094.xml                                           Justitie
#  KVR10095.xml                                           Justitie
#  KVR10096.xml                                           Defensie
#  KVR10097.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10098.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10099.xml                         Verkeer en Waterstaat (VW)
#  KVR1010.xml                 Onderwijs, Cultuur en Wetenschappen
#  KVR10100.xml                                          Financien
#  KVR10101.xml                         Verkeer en Waterstaat (VW)
#  KVR10102.xml                                    Financiën (FIN)
#  KVR10103.xml                                          Financien
#  KVR10104.xml                                           Defensie
#  KVR10105.xml            Volksgezondheid, Welzijn en Sport (VWS)
#  KVR10106.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10107.xml                  Volksgezondheid, Welzijn en Sport
#  KVR10108.xml                  Volksgezondheid, Welzijn en Sport
#
# [100 rows x 6 columns]

# %%
# want to know how this works?
pd.read_csv?

# %%
kvrdf.ministerie.value_counts().head(20)
# Out:
# nan                                                               13327
#  Justitie (JUS)                                                    3219
#  Volksgezondheid, Welzijn en Sport (VWS)                           2630
#  Buitenlandse Zaken (BUZA)                                         1796
#  Verkeer en Waterstaat (VW)                                        1441
#  Justitie                                                          1333
#  Sociale Zaken en Werkgelegenheid (SZW)                            1231
#  Onderwijs, Cultuur en Wetenschappen (OCW)                         1187
#  Volkshuisvesting, Ruimtelijke Ordening en Milieubeheer (VROM)      984
#  Financiën (FIN)                                                    960
#  Volksgezondheid, Welzijn en Sport                                  951
#  Economische Zaken (EZ)                                             946
#  Buitenlandse Zaken                                                 753
#  Binnenlandse Zaken en Koninkrijksrelaties (BZK)                    725
#  Verkeer en Waterstaat                                              724
#  Defensie (DEF)                                                     646
#  Sociale Zaken en Werkgelegenheid                                   607
#  Landbouw, Natuurbeheer en Visserij (LNV)                           586
#  Volkshuisvesting, Ruimtelijke Ordening en Milieubeheer             554
#  Onderwijs, Cultuur en Wetenschappen                                532
# Name: ministerie, dtype: int64

# %%
import nltk
from collections import Counter

# Join all titels of the questions together
allvragen= '\n'.join(list(kvrdf.titel))
print(len(allvragen), allvragen[:1000])
# Out:
# 10303543  De vragen betreffen de betrouwbaarheid van de geluidsmetingen op Schiphol.
#  Vragen naar aanleiding van berichten (uitzending NOVA 17 juli 1999) over onderzoeken van de Rijksrecherche waaruit blijt dat er twijfels bestaan over het professioneel gedrag van vier medewerkers van de kliniek.
#  Vragen naar aanleiding van de berichten "Nederland steunt Soeharto''s fiscaal" en "Wij hebben een naam hoog te houden" in NRC van 22 juli 1999.
#  Vragen over de gebrekkige opvang van verpleegkundigen met traumatische ervaringen door ziekenhuizen en zorginstellingen.
#  Vragen over onbetrouwbaarheid van filemeldingen.
#  Vragen naar aanleiding van het bericht in de Volkskrant van 7 juli 1999 dat het RIVM onjuiste gegevens zou hebben gehanteerd en gepresenteerd wat betreft de milieuaspecten van de Betuwelijn.
#
#  Vragen naar aanleiding van het artikel ''Eilander artsen vechten voor waarneming'' in de Leeuwarder Courant van 26 juni 1999. Deze vragen dienen ter aanvulling op eerdere vragen van de leden Van Bler

# %%
# Tokenize, lowercase  and turn into a bag of words
BoW= Counter(nltk.word_tokenize(allvragen.lower()))
print(len(BoW))
# show the top 20 most used words 
BoW.most_common(20)
# Out:
# 69043
# [('de', 111993),
#  ('van', 100165),
#  ('.', 52181),
#  ('het', 50597),
#  (',', 49262),
#  ('in', 37368),
#  ('en', 30991),
#  ('vragen', 28793),
#  ('een', 27655),
#  ('over', 22886),
#  ('op', 19956),
#  ('dat', 18682),
#  (')', 17990),
#  ('(', 17941),
#  ('te', 17473),
#  ('naar', 16996),
#  ('voor', 15479),
#  ('?', 15057),
#  ('is', 13587),
#  ('aanleiding', 12082)]

# %%
# remove stopwords, and tokens containing punctuation or numbers (note also removes "u2", "can't", etc)
from nltk.corpus import stopwords
DutchStop= stopwords.words('dutch')
print(len(DutchStop))

BoW=  Counter([w for w in nltk.word_tokenize(allvragen.lower()) if w.isalpha() and not w in set(DutchStop)])
print(len(BoW))
# show the top 20 most used words 
BoW.most_common(20)
# Out:
# 101
# 52483
# [('vragen', 28793),
#  ('aanleiding', 12082),
#  ('minister', 4675),
#  ('bericht', 4557),
#  ('artikel', 3299),
#  ('nederlandse', 3141),
#  ('indiener', 3124),
#  ('nederland', 3026),
#  ('welke', 2933),
#  ('nr', 2778),
#  ('eerdere', 2663),
#  ('betreft', 2519),
#  ('ingezonden', 2491),
#  ('ter', 2197),
#  ('ten', 2188),
#  ('onderzoek', 2166),
#  ('handelingen', 2078),
#  ('lid', 2027),
#  ('aanvulling', 1934),
#  ('waarin', 1880)]

# %%
# how many words occur just once?
# how many occur at least 5 times?

# %%
import pandas as pd
import timeit
import nltk
import math
import numpy
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from collections import Counter, defaultdict
from __future__ import division

# %%
names=['jaar', 'partij','titel','vraag','antwoord','ministerie']

# Change to KVR1000.csv.gz if this becomes to0 slow for you
kvrdf= pd.read_csv('http://maartenmarx.nl/teaching/zoekmachines/LectureNotes/MySQL/KVR.csv.gz', 
                   compression='gzip', sep='\t', 
                   index_col=0, names=names,
                   ) 
print(kvrdf.shape)
# Drop rows where ministerie is nan
kvrdf = kvrdf[kvrdf["ministerie"] == kvrdf["ministerie"]]
print(kvrdf.shape)
kvrdf.head(10)
# Out:
# (40516, 6)
# (27189, 6)
#                 jaar       partij  \
# KVR1000.xml     1994         PvdA
#  KVR10000.xml   1999         PvdA
#  KVR10001.xml   1999           SP
#  KVR10002.xml   1999         PvdA
#  KVR10003.xml   1999         PvdA
#  KVR10004.xml   1999          D66
#  KVR10006.xml   1999         PvdA
#  KVR10007.xml   1999          D66
#  KVR10008.xml   1999   GroenLinks
#  KVR10009.xml   1999           SP
#
#                                                            titel  \
# KVR1000.xml     De vragen betreffen de betrouwbaarheid van de...
#  KVR10000.xml   Vragen naar aanleiding van berichten (uitzend...
#  KVR10001.xml   Vragen naar aanleiding van de berichten "Nede...
#  KVR10002.xml   Vragen over de gebrekkige opvang van verpleeg...
#  KVR10003.xml   Vragen over onbetrouwbaarheid van filemeldingen.
#  KVR10004.xml   Vragen naar aanleiding van het bericht in de ...
#  KVR10006.xml
#  KVR10007.xml   Vragen naar aanleiding van het artikel ''Eila...
#  KVR10008.xml   Vragen over de mogelijke terugkeer naar het o...
#  KVR10009.xml   Vragen over de uiteindelijke invulling van ui...
#
#                                                            vraag  \
# KVR1000.xml     Hebt u kennisgenomen van het televisieprogram...
#  KVR10000.xml   Kent u de berichten over de situatie in de Me...
#  KVR10001.xml   Kent u de berichten «Nederland steunt de Soeh...
#  KVR10002.xml   Kent u het bericht over onderzoek van Nu91 me...
#  KVR10003.xml   Hebt u kennisgenomen van de berichten over de...
#  KVR10004.xml   Kent u het bericht als zou het RIVM onjuiste ...
#  KVR10006.xml   Kent u berichten over asbestgevaar voor KFOR-...
#  KVR10007.xml   Kent u het artikel Eilander artsen vechten vo...
#  KVR10008.xml   Kent u het artikel «De specialist declareert ...
#  KVR10009.xml   Is over de uiteindelijke invulling van de uit...
#
#                                                         antwoord  \
# KVR1000.xml     Ja. Het bedoelde geluidmeetpunt is eigendom v...
#  KVR10000.xml
#  KVR10001.xml
#  KVR10002.xml   Ja. Het onderzoek van NU’91 wijst uit dat het...
#  KVR10003.xml   Ja. Nee. Door de waarnemers van het Algemeen ...
#  KVR10004.xml   Ja. Nee. Als reactie op het Volkskrant-artike...
#  KVR10006.xml                          Kamerstuk 22 181, nr. 293
#  KVR10007.xml   Ja. Ik ben van mening, en ga er vanuit dat di...
#  KVR10008.xml   Ja. Neen, op dit moment is in drie van de rui...
#  KVR10009.xml   De Ziekenfondsraad, thans College voor zorgve...
#
#                                              ministerie
# KVR1000.xml                       Verkeer en Waterstaat
#  KVR10000.xml                                  Justitie
#  KVR10001.xml                                 Financien
#  KVR10002.xml         Volksgezondheid, Welzijn en Sport
#  KVR10003.xml                     Verkeer en Waterstaat
#  KVR10004.xml                     Verkeer en Waterstaat
#  KVR10006.xml                                  Defensie
#  KVR10007.xml         Volksgezondheid, Welzijn en Sport
#  KVR10008.xml   Volksgezondheid, Welzijn en Sport (VWS)
#  KVR10009.xml   Volksgezondheid, Welzijn en Sport (VWS)

# %%
# 1. Normalize values and choose 10 ministries to work with

ourMinisteries={"ustitie":"JUS",
                "olksgezondheid":"VWS",
                "erkeer":"VW", 
                "uitenlandse":"BUZA",
                "ociale":"SZW", 
                "ultuur":"OCW",
                "olkshuisvesting":"VROM",
                "inanc":"FIN", 
                "conomische":"EZ", 
                "oninkrijk":"BZK", 
                }
ourNormMinisteries=["JUS", "VWS", "VW", "BUZA", "SZW", "OCW", "VROM", "FIN", "EZ", "BZK"]

# Loop over index rows
for index, row in kvrdf.iterrows():
    print(index, end="\r")
    # Normalize selected ministeries
    if row.ministerie not in ourNormMinisteries:
        for key in ourMinisteries.keys():
            if key in row.ministerie:
                kvrdf.at[index, 'ministerie'] = ourMinisteries[key]
                break

# Remove unselected ministeries
kvrdf = kvrdf[ kvrdf['ministerie'].apply(lambda x: len(x)<5)]

print(kvrdf.shape)
kvrdf.head(100)
# Out:
# (23047, 6)0.xml
#                 jaar       partij  \
# KVR1000.xml     1994         PvdA
#  KVR10000.xml   1999         PvdA
#  KVR10001.xml   1999           SP
#  KVR10002.xml   1999         PvdA
#  KVR10003.xml   1999         PvdA
#  KVR10004.xml   1999          D66
#  KVR10007.xml   1999          D66
#  KVR10008.xml   1999   GroenLinks
#  KVR10009.xml   1999           SP
#  KVR10010.xml   1999          CDA
#  KVR10011.xml   1999          SGP
#  KVR10016.xml   1999          CDA
#  KVR10017.xml   1999           SP
#  KVR10018.xml   1999          CDA
#  KVR1002.xml    1994          GPV
#  KVR10020.xml   1999   GroenLinks
#  KVR10021.xml   1999          VVD
#  KVR10023.xml   1999         PvdA
#  KVR10025.xml   1999          CDA
#  KVR10027.xml   1999         PvdA
#  KVR1003.xml    1994          D66
#  KVR10031.xml   1999          CDA
#  KVR10037.xml   1999   GroenLinks
#  KVR10038.xml   1999           SP
#  KVR10039.xml   1999          CDA
#  KVR1004.xml    1994          AOV
#  KVR10040.xml   1999          GPV
#  KVR10044.xml   1999         PvdA
#  KVR10045.xml   1999          CDA
#  KVR10047.xml   1999   GroenLinks
# ...              ...          ...
#  KVR10103.xml   1999   GroenLinks
#  KVR10105.xml   1999          CDA
#  KVR10106.xml   1999   GroenLinks
#  KVR10107.xml   1999          CDA
#  KVR10108.xml   1999          CDA
#  KVR10109.xml   1999          CDA
#  KVR10114.xml   1999         PvdA
#  KVR10115.xml   1999           SP
#  KVR10116.xml   1999           SP
#  KVR10117.xml   1999         PvdA
#  KVR10118.xml   1999   GroenLinks
#  KVR1012.xml    1994          D66
#  KVR10120.xml   1999          CDA
#  KVR10121.xml   1999          CDA
#  KVR10123.xml   1999          VVD
#  KVR10125.xml   1999          RPF
#  KVR10126.xml   1999          VVD
#  KVR10127.xml   1999           SP
#  KVR10128.xml   1999          CDA
#  KVR1013.xml    1995   GroenLinks
#  KVR10131.xml   1999   GroenLinks
#  KVR10132.xml   1999          RPF
#  KVR10134.xml   1999           SP
#  KVR10135.xml   1999          CDA
#  KVR10136.xml   1999          CDA
#  KVR10137.xml   1999          CDA
#  KVR10138.xml   1999   GroenLinks
#  KVR10139.xml   1999           SP
#  KVR10140.xml   1999          CDA
#  KVR10142.xml   1999   GroenLinks
#
#                                                            titel  \
# KVR1000.xml     De vragen betreffen de betrouwbaarheid van de...
#  KVR10000.xml   Vragen naar aanleiding van berichten (uitzend...
#  KVR10001.xml   Vragen naar aanleiding van de berichten "Nede...
#  KVR10002.xml   Vragen over de gebrekkige opvang van verpleeg...
#  KVR10003.xml   Vragen over onbetrouwbaarheid van filemeldingen.
#  KVR10004.xml   Vragen naar aanleiding van het bericht in de ...
#  KVR10007.xml   Vragen naar aanleiding van het artikel ''Eila...
#  KVR10008.xml   Vragen over de mogelijke terugkeer naar het o...
#  KVR10009.xml   Vragen over de uiteindelijke invulling van ui...
#  KVR10010.xml   Aanvullende vragen op die gesteld door het li...
#  KVR10011.xml   Vragen over de introductie van de zogenaamde ...
#  KVR10016.xml   Vragen over het verbod van de Europese Commis...
#  KVR10017.xml   Vragen naar aanleiding van een geval van hulp...
#  KVR10018.xml   Vragen over de bestemming van grond die bij h...
#  KVR1002.xml    De vragen betreffen een voorgenomen voorstel ...
#  KVR10020.xml   Vragen over het hygienisch en/of steriel werk...
#  KVR10021.xml   Vragen over een bericht dat gerechtsdeurwaard...
#  KVR10023.xml   Vragen over de gevolgen van de proefboringen ...
#  KVR10025.xml   Vragen over versnelde verdubbeling van het aa...
#  KVR10027.xml   Vragen over de uitvoeringsregels PGB (persoon...
#  KVR1003.xml    De vragen betreffen een voorgenomen voorstel ...
#  KVR10031.xml   Vraag n.a.v. krantenbericht "Nederland is iet...
#  KVR10037.xml   Vragen over de rechtmatigheid van werklooshei...
#  KVR10038.xml   Vragen over aanpassingen van de werkplek voor...
#  KVR10039.xml   Vragen over de concept-beleidsregels van het ...
#  KVR1004.xml    Vragen betreffen de ''lozing met zachte drang...
#  KVR10040.xml   Vragen naar aanleiding van de wens die ambass...
#  KVR10044.xml   Vragen naar aanleiding van een artikel in FEM...
#  KVR10045.xml   Vragen naar aanleiding van het artikel ''Cont...
#  KVR10047.xml   Vragen over een landelijk beleid voor de plaa...
# ...                                                          ...
#  KVR10103.xml   Vragen naar aanleiding van het Teletekst-beri...
#  KVR10105.xml   Vragen naar aanleiding van een artikel in Spi...
#  KVR10106.xml   Vragen over de betrouwbaarheid van de Nederla...
#  KVR10107.xml   Vragen naar aanleiding van het bericht in Tro...
#  KVR10108.xml   Vragen gaan in op de fors opgelopen wachttijd...
#  KVR10109.xml   Vragen over de Nederlandse inzet bij de benoe...
#  KVR10114.xml   Vragen naar aanleiding van berichten, dat Ser...
#  KVR10115.xml   Vragen naar aanleiding van artikel in Spaanse...
#  KVR10116.xml   Vragen naar aanleiding van het bericht ''Poli...
#  KVR10117.xml   Vragen naar aanleiding van berichten dat de S...
#  KVR10118.xml   Het betreft meerdere vragen over de door de p...
#  KVR1012.xml    De vragen gaan over de gevolgen van de maatre...
#  KVR10120.xml   Gevraagd wordt onder meer of er discussie is ...
#  KVR10121.xml   Vragen over het gedogen van de verkoop van so...
#  KVR10123.xml   Vragen naar aanleiding van een bericht in NRC...
#  KVR10125.xml   Vragen naar aanleiding van berichten in het A...
#  KVR10126.xml   Vragen over de vacature bij de International ...
#  KVR10127.xml   Vragen over de toegankelijkheid van het openb...
#  KVR10128.xml   Vragen over het mogelijk stopzetten van de di...
#  KVR1013.xml    De vragen betreffen de buitenproportionele in...
#  KVR10131.xml   Vragen over het informeren van de Tweede Kame...
#  KVR10132.xml   Vragen naar aanleiding van de uitspraak van d...
#  KVR10134.xml   Vragen naar aanleiding van het bericht "Fiscu...
#  KVR10135.xml   Vragen naar aanleiding van het ANP-bericht va...
#  KVR10136.xml   Vragen gaan in op de modernisering van de reg...
#  KVR10137.xml   Vragen naar aanleiding van een bericht in het...
#  KVR10138.xml   Vragen naar aanleiding van een onderzoek van ...
#  KVR10139.xml   Betreft het recht op bijzondere bijstand. In ...
#  KVR10140.xml   Vragen over de stijging van de toeristenbelas...
#  KVR10142.xml   Vragen naar aanleiding van het vonnis van de ...
#
#                                                            vraag  \
# KVR1000.xml     Hebt u kennisgenomen van het televisieprogram...
#  KVR10000.xml   Kent u de berichten over de situatie in de Me...
#  KVR10001.xml   Kent u de berichten «Nederland steunt de Soeh...
#  KVR10002.xml   Kent u het bericht over onderzoek van Nu91 me...
#  KVR10003.xml   Hebt u kennisgenomen van de berichten over de...
#  KVR10004.xml   Kent u het bericht als zou het RIVM onjuiste ...
#  KVR10007.xml   Kent u het artikel Eilander artsen vechten vo...
#  KVR10008.xml   Kent u het artikel «De specialist declareert ...
#  KVR10009.xml   Is over de uiteindelijke invulling van de uit...
#  KVR10010.xml   Heeft u in een brief aan artsen, apothekers e...
#  KVR10011.xml   Kent u de berichtgeving rond de introductie v...
#  KVR10016.xml   Heeft de Europese Commissie de door de regeri...
#  KVR10017.xml   Hebt u kennisgenomen van de verslaglegging in...
#  KVR10018.xml   Komt bij het boren van tunnels grond vrij die...
#  KVR1002.xml    Heeft de Franse minister van Buitenlandse Zak...
#  KVR10020.xml   Hoeveel tatoeëerders en piercers zijn in Nede...
#  KVR10021.xml   Is het bericht waar dat ruim 55 gerechtsdeurw...
#  KVR10023.xml   Bent u op de hoogte van de gang van zaken bij...
#  KVR10025.xml   Is het u bekend dat de N31, met name het traj...
#  KVR10027.xml   Hebt u kennisgenomen van de brief van de Fede...
#  KVR1003.xml    Kent u uitspraken van de Franse minister voor...
#  KVR10031.xml   Hebt u kennisgenomen van de uitspraken van de...
#  KVR10037.xml   Herinnert u zich de antwoorden op de kamervra...
#  KVR10038.xml   Is het waar dat aanpassingen van de werkplek ...
#  KVR10039.xml   Bent u op de hoogte van de inhoud van de brie...
#  KVR1004.xml    Worden oudere patie¨nten, die als gevolg van ...
#  KVR10040.xml   Op welke wijze wilt u de door ambassadeur Van...
#  KVR10044.xml   Bent u op de hoogte van de nadere berichtgevi...
#  KVR10045.xml   Kent u het artikel «Controle in disco’s onder...
#  KVR10047.xml   Herinnert de staatssecretaris van Verkeer en ...
# ...                                                          ...
#  KVR10103.xml   Hebt u kennisgenomen van de laatste cijfers v...
#  KVR10105.xml   Is het u bekend dat de tabaksindustrie chemis...
#  KVR10106.xml   Kent u het bericht «Controle op dioxine deugt...
#  KVR10107.xml   Kent u het bericht dat «ziekenhuizen gespecia...
#  KVR10108.xml   Heeft u kennisgenomen van de ongerustheid van...
#  KVR10109.xml   Heeft de regering een Nederlandse kandidatuur...
#  KVR10114.xml   Wat is uw oordeel over het onlangs verschenen...
#  KVR10115.xml   Kent u het bericht dat de Spaanse procureur R...
#  KVR10116.xml   Kent u het bericht «Politiegeweld in Frankrij...
#  KVR10117.xml   Hebt u kennisgenomen van berichten in verschi...
#  KVR10118.xml   Zijn de berichten waar dat de provincie Zuid-...
#  KVR1012.xml    Krijgen honderden langdurig werkloze op werke...
#  KVR10120.xml   Is er naar aanleiding van recente jurispruden...
#  KVR10121.xml   Hebt u kennisgenomen van het besluit van de g...
#  KVR10123.xml   Kunt u een toelichting geven op het besluit o...
#  KVR10125.xml   Is het waar dat Avebe, ondanks het tot op hed...
#  KVR10126.xml   Kent u de belangrijke bijdrage die de Nederla...
#  KVR10127.xml   Bent u op de hoogte van het voornemen van NS ...
#  KVR10128.xml   Stopt de NS grotendeels met het verlenen van ...
#  KVR1013.xml    Beschouwt de Nederlandse regering het Russisc...
#  KVR10131.xml   Hebt u besloten de uitzettingen van Turkse Ko...
#  KVR10132.xml   Hebt u kennisgenomen van het onderzoek van dr...
#  KVR10134.xml   Kent u het bericht «Fiscus maakt zeven geheim...
#  KVR10135.xml   Hebt u kennisgenomen van het bericht in het D...
#  KVR10136.xml   Kent u het bericht dat door reizigers naar de...
#  KVR10137.xml   Hebt u kennisgenomen van het bericht dat uw a...
#  KVR10138.xml   Hebt u kennisgenomen van het onderzoek van de...
#  KVR10139.xml   Herinnert u zich het antwoord op kamervragen ...
#  KVR10140.xml   Kent u het krantenartikel met de titel: «Geme...
#  KVR10142.xml   Hebt u kennisgenomen van het vonnis van de re...
#
#                                                         antwoord ministerie
# KVR1000.xml     Ja. Het bedoelde geluidmeetpunt is eigendom v...         VW
#  KVR10000.xml                                                           JUS
#  KVR10001.xml                                                           FIN
#  KVR10002.xml   Ja. Het onderzoek van NU’91 wijst uit dat het...        VWS
#  KVR10003.xml   Ja. Nee. Door de waarnemers van het Algemeen ...         VW
#  KVR10004.xml   Ja. Nee. Als reactie op het Volkskrant-artike...         VW
#  KVR10007.xml   Ja. Ik ben van mening, en ga er vanuit dat di...        VWS
#  KVR10008.xml   Ja. Neen, op dit moment is in drie van de rui...        VWS
#  KVR10009.xml   De Ziekenfondsraad, thans College voor zorgve...        VWS
#  KVR10010.xml   Ja, het betreft zelfzorggeneesmiddelen die in...        VWS
#  KVR10011.xml   Ja. Het geneesmiddel Mifegyne betreft een gen...        VWS
#  KVR10016.xml   Deels. De Europese Commissie heeft een gedeel...        FIN
#  KVR10017.xml   Ja. Het betrof een geval van hulp bij zelfdod...        JUS
#  KVR10018.xml   Er komt inderdaad grond vrij dat vermengd wor...         VW
#  KVR1002.xml    Ja. Frankrijk is voornemens dit voorstel tijd...       BUZA
#  KVR10020.xml   Het is niet bekend hoeveel tatoeëerders en pi...        VWS
#  KVR10021.xml   Bijlage ter inzage gelegd bij de afdeling Par...        JUS
#  KVR10023.xml   Ja. De m.e.r.-procedure is inmiddels volledig...         EZ
#  KVR10025.xml   Ja, het is mij bekend dat zich op de N31, met...         VW
#  KVR10027.xml   Bijlagen ter inzage gelegd bij de afdeling Pa...        VWS
#  KVR1003.xml    Ja. Nee, minister Lamassoure heeft inmiddels ...       BUZA
#  KVR10031.xml   Ja. Blijkens een recente brief van de gemeent...       VROM
#  KVR10037.xml   Ja, met dien verstande dat het hierbij gaat o...        SZW
#  KVR10038.xml   Nee; zie voor een toelichting het antwoord op...        SZW
#  KVR10039.xml                                                           SZW
#  KVR1004.xml    Ook mij is dit verschijnsel uit krantebericht...        VWS
#  KVR10040.xml   Ambassadeur Van Walsum heeft in de VR uitdruk...       BUZA
#  KVR10044.xml   Ja. Wij betreuren het dat in ons eerdere antw...        JUS
#  KVR10045.xml   Ja. In samenwerking en overleg met de gemeent...        JUS
#  KVR10047.xml                                                            VW
# ...                                                          ...        ...
#  KVR10103.xml   Ja, waarbij ik opmerk dat het hier gaat om ee...        FIN
#  KVR10105.xml   Ook ik heb via de media moeten vernemen dat d...        VWS
#  KVR10106.xml   Ja. De rapportage van de inspectiemissie van ...        VWS
#  KVR10107.xml   Ja. Ik kan deze stelling bevestigen noch ontk...        VWS
#  KVR10108.xml   Ja. Bij brief van 8 juli 1999 heb ik van de P...        VWS
#  KVR10109.xml   De regering heeft geen Nederlandse kandidatuu...       BUZA
#  KVR10114.xml   Zoals ook aangegeven in de antwoorden op de e...       BUZA
#  KVR10115.xml   Ja. Ons is overigens niet bekend dat de Spaan...       BUZA
#  KVR10116.xml   Ja. Het Europese Hof voor de Rechten van de M...       BUZA
#  KVR10117.xml   Op vragen van overeenkomstige strekking die z...       BUZA
#  KVR10118.xml                                                           FIN
#  KVR1012.xml    Voor de Kaderregeling Bedrijfstakgewijze Scho...        SZW
#  KVR10120.xml                                                           FIN
#  KVR10121.xml   Ja. Het regionaal beleid ten aanzien van coff...        JUS
#  KVR10123.xml   Het kabinet heeft Uw Kamer eerder, laatstelij...       BUZA
#  KVR10125.xml   Zoals toegelicht in de antwoorden op de vrage...       VROM
#  KVR10126.xml   Ja. De zetel is niet in 1998 vacant gekomen m...        OCW
#  KVR10127.xml   Ik heb kennis genomen van de vragen en de ber...         VW
#  KVR10128.xml   Ik heb kennis genomen van eerdere berichten i...         VW
#  KVR1013.xml    Vanuit volkenrechtelijk oogpunt vormt de auto...       BUZA
#  KVR10131.xml   Vanwege een bericht dat een uitgeprocedeerde ...        JUS
#  KVR10132.xml                                                           FIN
#  KVR10134.xml   Ja. De geheimhoudingsplicht van artikel 67 Al...        FIN
#  KVR10135.xml   Ja. De regering heeft navraag gedaan bij de C...       BUZA
#  KVR10136.xml                                                           VWS
#  KVR10137.xml   Ik heb kennisgenomen van diverse krantenberic...        VWS
#  KVR10138.xml   Ja. Het onderzoek is in mijn opdracht uitgevo...         EZ
#  KVR10139.xml   Bijlage ter inzage gelegd bij afdeling Parlem...        SZW
#  KVR10140.xml   Ja. Uit de Monitor Lokale Lasten 1998 blijkt ...         EZ
#  KVR10142.xml   Ja. Er zullen geen consequenties aan de uitsp...       VROM
#
# [100 rows x 6 columns]

# %%
# Divide data into test and training sets:
kvrTrain = kvrdf[:18400]
kvrTest = kvrdf[18401:]
kvrTrain.shape
# Out:
# (18400, 6)

# %%
# From the previous assignment: Making an inverted index
def index_collection(docs):
    MyIndex= defaultdict(Counter) # initialize MyIndex
    count = len(docs)
    for index, doc in docs.iterrows():  # loop over each file
        print(count, end="\r")
        count -= 1
        f = doc.titel #+ doc.vraag + doc.antwoord
        text = [w for w in nltk.word_tokenize(f)]   # get text and tokenize
        for w in text:    # update MyIndex with each token 
            if not w.isupper(): # leave completely upper case words
                w = w.lower()   # lower case others
            MyIndex[w][index]+=1
    print('Done!')           
    return MyIndex

trainingIndex = index_collection(kvrTrain)
# Out:
# Done!

# %%
kvrdf.ministerie.value_counts()
# Out:
# JUS     5041
# VWS     3671
# BUZA    2795
# VW      2226
# OCW     1974
# SZW     1920
# VROM    1587
# FIN     1532
# EZ      1317
# BZK      982
#  MP        1
#  VI        1
# Name: ministerie, dtype: int64
